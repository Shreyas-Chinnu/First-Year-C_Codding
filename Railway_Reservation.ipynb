# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyas-Chinnu/First-Year-C_Codding/blob/master/Railway_Reservation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/content/Dataset/Basic Project Railway Management System in SQL.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(10,5)

# %%
df=pd.read_csv('/content/Dataset/Basic Project Railway Management System in SQL.csv')

# %%
df_out=pd.read_csv('/content/Dataset/Basic Project Railway Management System in SQL.csv')

# %%
df.head()
# Out:
#    Train_id       Train_name Train_type  Coaches    PNR_no First_name  \
# 0     12490  Samparak_Kranti    Express       25  45327839      Sneha
# 1     11450   Varanasi Super    Express       25  47836904      Rahul
# 2     42999           Memu 2  Passenger       10  45527842       Amit
# 3     80124      Vandebharat  Superfast       20  45627843       Neha
# 4     71424   Shanti Express    Express       22  45727844      Rajat
#
#   Last_name     Contact           Email_id  Booking_id  ... Unnamed: 991  \
# 0      Jain  9876543210  sneha@example.com           6  ...          NaN
# 1     Verma  8765432109  rahul@example.com           7  ...          NaN
# 2     Yadav  9876543211   amit@example.com           8  ...          NaN
# 3     Singh  8765432108   neha@example.com           9  ...          NaN
# 4    Mishra  9876543212  rajat@example.com          10  ...          NaN
#
#   Unnamed: 992 Unnamed: 993  Unnamed: 994 Unnamed: 995 Unnamed: 996  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Columns: 1001 entries, Train_id to Unnamed: 1000
# dtypes: bool(1), float64(980), int64(8), object(12)
# memory usage: 117.3+ KB

# %%
df.describe()
# Out:
#            Train_id    Coaches        PNR_no       Contact  Booking_id  \
# count     15.000000  15.000000  1.500000e+01  1.500000e+01   15.000000
# mean   38361.000000  20.066667  4.582578e+07  9.384315e+09    8.000000
# std    23063.960297   4.787882  6.822360e+05  5.077367e+08    4.472136
# min    11450.000000  10.000000  4.502785e+07  8.765432e+09    1.000000
# 25%    14802.500000  18.000000  4.532784e+07  8.765687e+09    4.500000
# 50%    42999.000000  20.000000  4.572784e+07  9.545789e+09    8.000000
# 75%    52355.000000  24.500000  4.607785e+07  9.876543e+09   11.500000
# max    80124.000000  25.000000  4.783690e+07  9.935678e+09   15.000000
#
#        Seat_alloted  Duration_minutes         Fair  Unnamed: 21  Unnamed: 22  \
# count     15.000000         15.000000    15.000000          0.0          0.0
# mean       4.600000        226.000000   609.333333          NaN          NaN
# std        2.472708        146.082169   350.478584          NaN          NaN
# ...

# %%
df.shape
# Out:
# (15, 1001)

# %%
df.columns
# Out:
# Index(['Train_id', 'Train_name', 'Train_type', 'Coaches', 'PNR_no',
#        'First_name', 'Last_name', 'Contact', 'Email_id', 'Booking_id',
#        ...
#        'Unnamed: 991', 'Unnamed: 992', 'Unnamed: 993', 'Unnamed: 994',
#        'Unnamed: 995', 'Unnamed: 996', 'Unnamed: 997', 'Unnamed: 998',
#        'Unnamed: 999', 'Unnamed: 1000'],
#       dtype='object', length=1001)

# %%
df1=df.groupby(['Train_id','Train_name'],as_index=False).count()

# %%
df1.Train_name.value_counts()
# Out:
# Train_name
# Varanasi Super        1
# Samparak_Kranti       1
# Mahamna               1
# Darbhanga Expresss    1
# Memu                  1
# Local                 1
# Ambedkar Express      1
# Memu 2                1
# Enter_City            1
# Shatabdi              1
# Chambal               1
# Duronto Express       1
# Rajdhani              1
# Shanti Express        1
# Vandebharat           1
# Name: count, dtype: int64

# %%
df2=df.groupby(['Train_id','Train_name','Coaches'],as_index=False).count()
df2['Train_id'].value_counts()
# Out:
# Train_id
# 11450    1
# 12490    1
# 14228    1
# 14789    1
# 14816    1
# 25473    1
# 25486    1
# 42999    1
# 47111    1
# 47941    1
# 48231    1
# 56479    1
# 62374    1
# 71424    1
# 80124    1
# Name: count, dtype: int64

# %%
df3=df.groupby(['Train_id','Train_name','Coaches'],as_index=False).count()
df3['Coaches'].value_counts()
# Out:
# Coaches
# 25    4
# 20    3
# 18    2
# 22    2
# 12    1
# 24    1
# 10    1
# 15    1
# Name: count, dtype: int64

# %%
sns.boxplot(data=df,x=df['Train_id'],y=df['Coaches'])
# Out:
# <Axes: xlabel='Train_id', ylabel='Coaches'>

# %%
sns.lineplot(data=df,x='Train_id',y='Train_name',hue='Coaches')
# Out:
# <Axes: xlabel='Train_id', ylabel='Train_name'>
